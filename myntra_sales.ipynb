# %% [markdown]
# ### Task1

# %% [markdown]
# #### Import all the relevant packages (Eg: Numpy, Seaborn...)

# %%
#importing liabraries for analysis.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
#importing data.
pro_details=pd.read_csv("product details.csv")
pro_details.head()
# Out:
#    ProductID                                        ProductName ProductBrand
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx

# %%
#importing table.
pro_catlog=pd.read_csv("products catalog.csv")
pro_catlog.head()
# Out:
#   Gender  Price (INR)  NumImages        ID  \
# 0  Women          593          5  10182131
# 1    Men         6396          5  10052169
# 2  Women          599          5  10168643
# 3    Men         1034          5  10155427
# 4    Men          477          3  10191059
#
#                                          Description PrimaryColor
# 0  Off-White printed woven A-line  top, has a rou...        White
# 1  Display: AnalogueMovement: QuartzPower source:...        Black
# 2  Blue printed knitted regular  top, has a high ...         Blue
# 3  Grey and Purple checked smart casual shirt, ha...         Grey
# 4  Beige and Brown striped beltReversible: NoStre...        Brown

# %%
#analysing shape of dataset.
pro_details.shape
# Out:
# (12491, 3)

# %%
#analysing shape of dataset.
pro_catlog.shape
# Out:
# (12491, 6)

# %% [markdown]
# The shapes of both dataframe have same number of rows and different number of column.

# %%
#checking for information of data.
pro_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 292.9+ KB

# %%
#checking for information.
pro_catlog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Gender        12491 non-null  object
#  1   Price (INR)   12491 non-null  int64
#  2   NumImages     12491 non-null  int64
#  3   ID            12491 non-null  int64
#  4   Description   12491 non-null  object
#  5   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 585.6+ KB

# %%
#5 point summary of dataset.
pro_details.describe()
# Out:
#           ProductID
# count  1.249100e+04
# mean   9.917160e+06
# std    1.438006e+06
# min    1.012060e+05
# 25%    1.006215e+07
# 50%    1.015463e+07
# 75%    1.021565e+07
# max    1.027514e+07

# %%
# 5 point summary of dataset.
pro_catlog.describe()
# Out:
#         Price (INR)     NumImages            ID
# count  12491.000000  12491.000000  1.249100e+04
# mean    1452.660956      4.913698  9.917160e+06
# std     2118.503976      1.092333  1.438006e+06
# min       90.000000      1.000000  1.012060e+05
# 25%      649.000000      5.000000  1.006215e+07
# 50%      920.000000      5.000000  1.015463e+07
# 75%     1499.000000      5.000000  1.021565e+07
# max    63090.000000     10.000000  1.027514e+07

# %% [markdown]
# After checking 5 point summary in pro_details no important numerical varible is there for EDA and in pro_catlog the important
# variable is price and number of image is important for EDA.

# %%
# checking for null values.
pro_details.isnull().sum()
# Out:
# ProductID       0
# ProductName     0
# ProductBrand    0
# dtype: int64

# %%
#checking for null values.
pro_catlog.isnull().sum()
# Out:
# Gender            0
# Price (INR)       0
# NumImages         0
# ID                0
# Description       0
# PrimaryColor    894
# dtype: int64

# %% [markdown]
# In pro_details dataset no null values are presence but in pro_catlog dataframe null values are present in primarycolor column.

# %% [markdown]
# ### Task2

# %% [markdown]
# #### Create a new dataframe “df” by joining the 2 datasets

# %%
#renaming columnname.
pro_details.rename(columns = {'ProductID':'ID'}, inplace = True)

# %%
#creating new dataframe. 
df=pd.merge(pro_details,pro_catlog)
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %%
#shape of dataframe after merging.
df.shape
# Out:
# (12491, 8)

# %% [markdown]
# #### Drop duplicate values.

# %%
#dropping duplicate values.
df.drop_duplicates()
# Out:
#              ID                                        ProductName  \
# 0      10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1      10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2      10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3      10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4      10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...         ...                                                ...
# 12486  10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487  10261721                 Mochi Women Gold-Toned Solid Heels
# 12488  10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489  10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490  10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# 1       EthnoVogue   Women         5810          7
# ...

# %% [markdown]
# After dropping duplicate values found no change in shape of datframe which means no duplicate values are presemt in dataframe.

# %% [markdown]
# #### Check for missing values.

# %%
#check for null values in dataframe.
df.isnull().sum()
# Out:
# ID                0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %% [markdown]
# From above details we can see that PrimaryColor column have null values now we have to treat this null values.

# %% [markdown]
# #### There is a column that needs string strip operation. Identify that and apply it.

# %%
#strip function to remove extra chars.
df['ProductBrand'].str.strip().head()
# Out:
# 0          DKNY
# 1    EthnoVogue
# 2        SPYKAR
# 3       Raymond
# 4          Parx
# Name: ProductBrand, dtype: object

# %%
#removing leading and trailing space from description.
df['Description'].str.strip().head()
# Out:
# 0    Black and grey printed medium trolley bag, sec...
# 1    Beige & Grey made to measure kurta with churid...
# 2    Pink coloured wash 5-pocket high-rise cropped ...
# 3    Blue self-design bandhgala suitBlue self-desig...
# 4    Brown and off-white printed casual shirt, has ...
# Name: Description, dtype: object

# %% [markdown]
# #### Fill the missing value by ‘Others’ in the column containing it

# %%
#filli missing values and verifying as well.
df.fillna("Others",inplace=True)
df.isnull().sum()
# Out:
# ID              0
# ProductName     0
# ProductBrand    0
# Gender          0
# Price (INR)     0
# NumImages       0
# Description     0
# PrimaryColor    0
# dtype: int64

# %% [markdown]
#  Now, no null values are present in dataset all missing values are filled.

# %% [markdown]
# #### Since all the column names are single word so you can convert the ‘Price (INR)’ also to single name ‘Price’.

# %%
#renaming column with rename function.
df.rename(columns = {'Price (INR)':'Price'}, inplace = True)
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# ...

# %% [markdown]
# We can see that the name of ‘Price (INR)’ is changed to ‘Price (INR)’.

# %% [markdown]
# #### Analyse the Gender column and include your viewpoints how to make it useful.

# %%
#counting total values of each category in gender.
df['Gender'].value_counts()
# Out:
# Women          5126
# Men            4591
# Unisex         1188
# Boys           1100
# Girls           440
# Unisex Kids      46
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(8,20))
sns.scatterplot(x='Gender',y='ProductBrand',data=df)
plt.show()

# %% [markdown]
# ### Observations:
# * We can see women are the most focused on product brand then any other category in gender columns.
# * In unisex kids category of gender column very few one shops according product brands.

# %%
#checking which color is mostly purchased by customers.
df['PrimaryColor'].value_counts()
# Out:
# Blue         3443
#  Black       1640
#  Red         1543
#  Green        908
# Others        894
#  White        880
#  Grey         684
#  Brown        473
#  Yellow       406
#  Pink         391
#  Gold         236
#  Beige        236
#  Maroon       187
#  Orange       130
#  Silver       111
#  Purple        65
#  Burgundy      64
#  Khaki         56
#  Navy          54
#  Lavender      19
#  Matte         17
#  Mustard       15
#  Magenta       13
#  Charcoal      10
#  Rose           8
#  Platinum       3
#  Bronze         3
#  Peach          2
# Name: PrimaryColor, dtype: int64

# %%
#ploting graph for gender and primarycolor to see relation.
plt.figure(figsize=(5,4))
sns.catplot(x='Gender',y='PrimaryColor',data=df,kind='strip')

# %% [markdown]
# #### Observations:
# * We can see women are most consistent in colorwise shopping habits then any other category in gender columns.
# * In unisex kids category of this column very few one shops according product brands.

# %%
#plotting graph between gender and number of images.
plt.figure(figsize=(8,5))
sns.catplot(x='Gender',y='NumImages',data=df,kind='bar',palette='rainbow')

# %% [markdown]
# #### Observations:
# * When check for number of images for shopping then men took decision on the basis of numimages available.
# * Boys ,Girls are exact equal but little difference with unisex kids category.

# %%
#plotting graph to see pricewise assosiation of gender column.
sns.catplot(x='Gender',y='Price',data=df,kind='bar',palette='rainbow_r')
plt.show()

# %% [markdown]
# #### Observation:
# * In price wise trend we can observe that unisex product have more sales.

# %% [markdown]
# #### All Observation from Gender column:
# * Women are most consistent than any other category in column as they are more detailed oriented than others.
# * Number of attractive images of product atrract men to shop more than others.
# * In unisex product range price does not make any impact to shop.

# %% [markdown]
# #### Univariate analysis of each variable

# %%
#categorical data analysis. 
df['ProductName'].value_counts()
# Out:
# Parx Men Blue Slim Fit Checked Casual Shirt                                          16
# ZHEIA Women Blue Skinny Fit Mid-Rise Clean Look Stretchable Jeans                    15
# Roadster Men Blue Skinny Fit Mid-Rise Clean Look Stretchable Jeans                   14
# Sonari Pack of 2 Full-Coverage Bras                                                  14
# Roadster Men Blue Slim Fit Mid-Rise Clean Look Stretchable Jeans                     13
#                                                                                      ..
# HRX by Hrithik Roshan Ultralyte Men Navy Blue Solid Running T-shirt                   1
# Flying Machine Men Blue Michael Tapered Fit Mid-Rise Clean Look Stretchable Jeans     1
# FAUSTO Men Red Slip-On Sneakers                                                       1
# Indian Terrain Boys Rust Brown Printed Round Neck T-shirt                             1
# Pepe Jeans Men Black & Grey Striped Polo Collar T-shirt                               1
# ...

# %%
#univariate analysis of ProductBrand.
df['ProductBrand'].value_counts()
# Out:
# Indian Terrain                  971
# Puma                            345
# Pepe Jeans                      340
# AURELIA                         307
# Flying Machine                  301
#                                ...
# Johnny Bravo by Kook N Keech      1
# Allen Solly Sport                 1
# HAMMER                            1
# CUTECUMBER                        1
# Stupid Cupid                      1
# Name: ProductBrand, Length: 677, dtype: int64

# %% [markdown]
# from here we can conclude that 'indian terrain' brand have max number of count.

# %%
#univariate analysis of ProductBrand column.
plt.figure(figsize=(18,5))
sns.countplot(x='ProductBrand',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
#univariate analysis of gender column.
df.groupby(['Gender']).sum().plot(kind='pie',autopct='%1.0f%%',y='Price').get_legend().remove()

# %% [markdown]
# Form this graph it is clearly visible that Men has maximum percentage of shopping without affected by price.

# %%
#univariate analysis of numimages column.
sns.countplot(x='NumImages',data=df,palette='gist_rainbow')
plt.show()

# %% [markdown]
# We can easily identify that maximum product have the number of images count is 5.

# %%
#univariate analysis of primary color column.
plt.figure(figsize=(10,5))
sns.countplot(x='PrimaryColor',data=df,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From here we can visualize that blue color hase the maximum value count so we can say that blue color is the most ordered color by customers.

# %% [markdown]
# ### Bivariate Analysis of categorical vs numerical variables.

# %%
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# ...

# %% [markdown]
# From above dataframe we can see that price is only numerical value which help us in analysis and it is depandent to almost all of the other columns of datasert so that e can take price as our target variable.

# %%
#analysis of gender by price.
plt.figure(figsize=(8,4))
sns.barplot(x='Gender',y='Price',data=df,palette='Accent')
plt.show()

# %% [markdown]
# from here we can conclude that unisex category product has the highest price beared by customers.

# %%
#ploting graph for price and productbrand.
plt.figure(figsize=(15,3))
sns.scatterplot(x='ProductBrand',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#analysis of numimages with price.
plt.figure(figsize=(6,3))
sns.scatterplot(x='NumImages',y='Price',data=df)
plt.show()

# %% [markdown]
# Here it is clear that number of images associated with product has not much impact on price but we can observe that the data is distributed normally between this two variable if we ignore some outliers in this graph.

# %%
#analysis of price and primarycolor.
sns.scatterplot(x='PrimaryColor',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From this visualization we can observe that 'black','blue','white' and 'silver' colors are most prefered colors over price which means customers choose to buy this colors without taking care of price.

# %% [markdown]
# #### Multivariate Analysis of categorical and numerical variables

# %%
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3  Blue self-design bandhgala suitBlue self-desig...         Blue
# ...

# %%
#multivariate analysis for numerical variables.
# sns.pairplot(data=df,size=2)
# plt.tight_layout()
# plt.show()
plt.figure(figsize=(5,5))
pd.plotting.scatter_matrix(df,diagonal='kde')
plt.show()

# %% [markdown]
# #### Check distribution of variables

# %%
df.head(2)
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige

# %%
#distribution of data.
plt.figure(figsize=(5,5))
sns.distplot(df['Price'])
plt.show()

# %% [markdown]
# From this distribution we can see density and can observe that the price variable is positively skewed.

# %%
#checking distribution of priarycolor variable.
plt.figure(figsize=(5,10))
sns.displot(df['PrimaryColor'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can observe that blue,black and red colors have the maximum count of order.

# %%
#distribution of number of images.
sns.distplot(df['NumImages'])
plt.show()

# %% [markdown]
# This distribution is normally distributed means it has a positive impact on product to gain customer's attention.

# %% [markdown]
# #### Create a new Column “NewGender” to analyse further its distribution. Going forward we will consider this group for tasks

# %%
#counting values of each category.
df['Gender'].value_counts()
# Out:
# Women          5126
# Men            4591
# Unisex         1188
# Boys           1100
# Girls           440
# Unisex Kids      46
# Name: Gender, dtype: int64

# %%
#combining different category into one and creating a new variable in dataset i.e. NewGender.
df['NewGender']=df['Gender'].replace({'Boys':'Men','Girls':'Women','Unisex Kids':'Unisex'})
df['NewGender'].value_counts()
# Out:
# Men       5691
# Women     5566
# Unisex    1234
# Name: NewGender, dtype: int64

# %%
#verifying dataframe after adding new column into dataset.
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# #### Complete the analysis of NewGender along with other categorical cols.

# %%
#plotting graph for categorical cols in association with newgender.
# sns.scatterplot(data=df,x='ProductName',y='NewGender')
# plt.xticks(rotation=90)
# plt.show()

# %%
#plotting graph for categorical cols in association with newgender.
plt.figure(figsize=(5,15))
sns.scatterplot(data=df,x='NewGender',y='ProductBrand')
plt.show()

# %% [markdown]
# After adding the related values with similar category we can see consistency in all the category now all brands worked equally in almost all category.

# %%
#plotting graph for categorical cols in association with newgender.
plt.figure(figsize=(6,6))
sns.scatterplot(data=df,x='NewGender',y='PrimaryColor')
plt.show()

# %% [markdown]
# This newcolumn also shows the consistency of women in color choice.

# %%
#analysis for categorical cols in association with newgender.
df.groupby
# Out:
# <bound method DataFrame.groupby of              ID                                        ProductName  \
# 0      10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1      10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2      10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3      10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4      10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...         ...                                                ...
# 12486  10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487  10261721                 Mochi Women Gold-Toned Solid Heels
# 12488  10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489  10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490  10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price  NumImages  \
# 0             DKNY  Unisex  11745          7
# ...

# %% [markdown]
# #### Create a new Column “DescriptionLength” to analyse further its distribution.

# %%
#checking total value and  details of description.
df['Description'].value_counts().head(3)
# Out:
# Blue medium wash 5-pocket mid-rise jeans, clean look, heavy fade, has a button and zip closure, and waistband with belt loops    54
# Blue medium wash 5-pocket mid-rise jeans, clean look, light fade, has a button and zip closure, and waistband with belt loops    47
# Black printed T-shirt, has a round neck, and short sleeves                                                                       36
# Name: Description, dtype: int64

# %%
#craeting a new column into dataframe.
df['DescriptionLength']=df['Description'].apply(lambda x:len(x))

# %%
#verifying that the new column is added or not.
df.head()
# Out:
#          ID                                        ProductName ProductBrand  \
# 0  10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1  10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2  10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3  10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4  10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender  \
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# #### Complete the analysis of DescriptionLength along with other categorical cols.

# %%
#analysis of descriptionlnght with category cols.
df['DescriptionLength'].value_counts()
# Out:
# 125    220
# 108    185
# 123    179
# 124    168
# 118    166
#       ...
# 453      1
# 15       1
# 478      1
# 479      1
# 748      1
# Name: DescriptionLength, Length: 721, dtype: int64

# %%
#analysis of descriptionlength with all cols.
df.groupby(['NewGender']).sum().plot(kind='pie',y='DescriptionLength',radius=1.2,autopct='%1.1f')
plt.show()

# %%
#analysis of descriptionlength with all cols.
df.groupby(['NumImages']).sum().plot(kind='pie',y='DescriptionLength',radius=2.5,autopct='%1.1f').get_legend().remove()
plt.show()

# %%
#analysis of descriptionlength with all cols.
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x='PrimaryColor',y='DescriptionLength')
plt.xticks(rotation=90)
plt.show()

# %%
#analysis of descriptionlength with all cols.
df.groupby('DescriptionLength')['Description'].value_counts().max()
# Out:
# 54

# %%
#analysis of descriptionlength with all cols.
df[['DescriptionLength','ProductName']].groupby('DescriptionLength')['ProductName'].value_counts().sort_values(ascending=False).head(10)
# Out:
# DescriptionLength  ProductName
# 107                Parx Men Blue Slim Fit Checked Casual Shirt                            12
# 114                Next Look Men Blue Slim Fit Self Design Formal Shirt                   12
# 57                 Indian Terrain Boys White Printed Round Neck T-shirt                    8
# 46                 Archies Love Gifts White & Black Ceramic Mug for Valentine              8
# 125                Roadster Men Blue Skinny Fit Mid-Rise Clean Look Stretchable Jeans      8
# 203                Homesake Gold-Toned & White Solid Handcrafted Table Lamp with Shade     7
# 58                 Flying Machine Men Black Printed Round Neck T-shirt                     7
# 1236               Daily Life Forever52 Women Pink Super Stay Lip Gloss 7ml                7
# 110                Next Look Men Blue Slim Fit Printed Formal Shirt                        6
# 107                Parx Men Blue Slim Fit Printed Casual Shirt                             6
# ...

# %%
#analysis of descriptionlength with all cols.
df.groupby('DescriptionLength')['ProductBrand'].value_counts().sort_values(ascending=False).head(10)
# Out:
# DescriptionLength  ProductBrand
# 125                Flying Machine    41
# 124                Indian Terrain    36
# 118                Indian Terrain    34
# 46                 Archies           30
# 262                Bodycare          30
# 125                Roadster          30
# 123                Indian Terrain    29
# 57                 Indian Terrain    28
# 119                Indian Terrain    27
# 117                Indian Terrain    24
# Name: ProductBrand, dtype: int64

# %%
#analysis of descriptionlength with all cols.
df.groupby('Price')['DescriptionLength'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Price  DescriptionLength
# 699    46                   30
# 820    262                  29
# 449    57                   23
# 1299   125                  23
# 449    58                   23
# 699    56                   20
#        72                   19
# 919    125                  18
# 699    55                   18
# 1299   124                  16
# Name: DescriptionLength, dtype: int64

# %% [markdown]
# #### Isn’t it important to check if attribute information is also included in Description? Complete this task before answering it.

# %% [markdown]
# Description of a product is a very important part of any product on e-commerce site, and yes all the attribute should include in description because a customer always prefer to check the description of the product he/she want to order.

# %% [markdown]
# ### Insights:
# * 'Gender' variable is most important feature of this dataset with this we able to analyse the trend of shopping.
# * 'Primary Color' is also important followed by 'Number of images' and 'Description' as well .
# * 'women' are more shpoholic and 'price' doen't affect them as much from purchasing.

# %% [markdown]
# ### * * * * * * * * * * * * * * * *   End Of Project   * * * * * * * * * * * * * * * * *
